# %% [markdown]
# # 00 — Setup & Environment Check
# Weryfikacja środowiska, instalacja brakujących pakietów, test importów.

# %%
import subprocess, sys
req = '../requirements.txt'
subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-r', req])
# Out:
# Requirement already satisfied: torch in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 1)) (2.12.0)
# Requirement already satisfied: torchvision in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 2)) (0.27.0)
# Requirement already satisfied: insightface in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 3)) (1.0.1)
# Requirement already satisfied: onnxruntime-gpu in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 4)) (1.26.0)
# Requirement already satisfied: chromadb in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 5)) (1.5.9)
# Requirement already satisfied: gdown in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 6)) (6.1.0)
# Requirement already satisfied: google-api-python-client in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 7)) (2.197.0)
# Requirement already satisfied: google-auth-oauthlib in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 8)) (1.4.0)
# Requirement already satisfied: matplotlib in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 9)) (3.11.0)
# Requirement already satisfied: scikit-learn in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 10)) (1.9.0)
# Requirement already satisfied: filelock in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 1)) (3.29.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: setuptools<82 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 1)) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 1)) (3.6.1)
# Requirement already satisfied: jinja2 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 1)) (2026.4.0)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->-r ../requirements.txt (line 1)) (13.0.2)
# Requirement already satisfied: nvidia-cublas<=13.1.1.3,>=13.1.0.3 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 1)) (13.1.1.3)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 1)) (13.3.1)
# Requirement already satisfied: nvidia-cudnn-cu13==9.20.0.48 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 1)) (9.20.0.48)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.1 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 1)) (0.8.1)
# Requirement already satisfied: nvidia-nccl-cu13==2.29.7 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 1)) (2.29.7)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 1)) (3.4.5)
# Requirement already satisfied: triton==3.7.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 1)) (3.7.0)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->-r ../requirements.txt (line 1)) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->-r ../requirements.txt (line 1)) (12.0.0.61)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->-r ../requirements.txt (line 1)) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->-r ../requirements.txt (line 1)) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->-r ../requirements.txt (line 1)) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->-r ../requirements.txt (line 1)) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->-r ../requirements.txt (line 1)) (12.6.3.3)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->-r ../requirements.txt (line 1)) (13.0.88)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->-r ../requirements.txt (line 1)) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->-r ../requirements.txt (line 1)) (13.0.85)
# Requirement already satisfied: numpy in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from torchvision->-r ../requirements.txt (line 2)) (2.4.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from torchvision->-r ../requirements.txt (line 2)) (12.2.0)
# Requirement already satisfied: onnx in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from insightface->-r ../requirements.txt (line 3)) (1.21.0)
# Requirement already satisfied: onnxruntime in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from insightface->-r ../requirements.txt (line 3)) (1.26.0)
# Requirement already satisfied: opencv-python in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from insightface->-r ../requirements.txt (line 3)) (4.13.0.92)
# Requirement already satisfied: tqdm in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from insightface->-r ../requirements.txt (line 3)) (4.68.2)
# Requirement already satisfied: requests in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from insightface->-r ../requirements.txt (line 3)) (2.34.2)
# Requirement already satisfied: scipy in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from insightface->-r ../requirements.txt (line 3)) (1.17.1)
# Requirement already satisfied: scikit-image in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from insightface->-r ../requirements.txt (line 3)) (0.26.0)
# Requirement already satisfied: flatbuffers in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from onnxruntime-gpu->-r ../requirements.txt (line 4)) (25.12.19)
# Requirement already satisfied: packaging in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from onnxruntime-gpu->-r ../requirements.txt (line 4)) (26.2)
# Requirement already satisfied: protobuf in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from onnxruntime-gpu->-r ../requirements.txt (line 4)) (6.33.6)
# Requirement already satisfied: build>=1.0.3 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from chromadb->-r ../requirements.txt (line 5)) (1.5.0)
# Requirement already satisfied: pydantic>=2.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from chromadb->-r ../requirements.txt (line 5)) (2.13.4)
# Requirement already satisfied: pydantic-settings>=2.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from chromadb->-r ../requirements.txt (line 5)) (2.14.1)
# Requirement already satisfied: pybase64>=1.4.1 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from chromadb->-r ../requirements.txt (line 5)) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r ../requirements.txt (line 5)) (0.49.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from chromadb->-r ../requirements.txt (line 5)) (1.42.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from chromadb->-r ../requirements.txt (line 5)) (1.42.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from chromadb->-r ../requirements.txt (line 5)) (1.42.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from chromadb->-r ../requirements.txt (line 5)) (0.23.1)
# Requirement already satisfied: pypika>=0.48.9 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from chromadb->-r ../requirements.txt (line 5)) (0.51.1)
# Requirement already satisfied: overrides>=7.3.1 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from chromadb->-r ../requirements.txt (line 5)) (7.7.0)
# Requirement already satisfied: importlib-resources in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from chromadb->-r ../requirements.txt (line 5)) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from chromadb->-r ../requirements.txt (line 5)) (1.81.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from chromadb->-r ../requirements.txt (line 5)) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from chromadb->-r ../requirements.txt (line 5)) (0.25.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from chromadb->-r ../requirements.txt (line 5)) (36.0.2)
# Requirement already satisfied: tenacity>=8.2.3 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from chromadb->-r ../requirements.txt (line 5)) (9.1.4)
# Requirement already satisfied: pyyaml>=6.0.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from chromadb->-r ../requirements.txt (line 5)) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from chromadb->-r ../requirements.txt (line 5)) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from chromadb->-r ../requirements.txt (line 5)) (3.11.9)
# Requirement already satisfied: httpx>=0.27.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from chromadb->-r ../requirements.txt (line 5)) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from chromadb->-r ../requirements.txt (line 5)) (15.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from chromadb->-r ../requirements.txt (line 5)) (4.26.0)
# Requirement already satisfied: beautifulsoup4 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from gdown->-r ../requirements.txt (line 6)) (4.15.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from google-api-python-client->-r ../requirements.txt (line 7)) (0.31.2)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from google-api-python-client->-r ../requirements.txt (line 7)) (2.54.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from google-api-python-client->-r ../requirements.txt (line 7)) (0.4.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from google-api-python-client->-r ../requirements.txt (line 7)) (2.31.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from google-api-python-client->-r ../requirements.txt (line 7)) (4.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from google-auth-oauthlib->-r ../requirements.txt (line 8)) (2.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from matplotlib->-r ../requirements.txt (line 9)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from matplotlib->-r ../requirements.txt (line 9)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from matplotlib->-r ../requirements.txt (line 9)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from matplotlib->-r ../requirements.txt (line 9)) (1.5.0)
# Requirement already satisfied: pyparsing>=3 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from matplotlib->-r ../requirements.txt (line 9)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from matplotlib->-r ../requirements.txt (line 9)) (2.9.0.post0)
# Requirement already satisfied: joblib>=1.4.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from scikit-learn->-r ../requirements.txt (line 10)) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from scikit-learn->-r ../requirements.txt (line 10)) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from scikit-learn->-r ../requirements.txt (line 10)) (3.6.0)
# Requirement already satisfied: pyproject_hooks in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from build>=1.0.3->chromadb->-r ../requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: cuda-pathfinder>=1.4.2 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from cuda-bindings<14,>=13.0.3->torch->-r ../requirements.txt (line 1)) (1.5.5)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client->-r ../requirements.txt (line 7)) (1.75.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.24.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client->-r ../requirements.txt (line 7)) (1.28.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client->-r ../requirements.txt (line 7)) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client->-r ../requirements.txt (line 7)) (49.0.0)
# Requirement already satisfied: anyio in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb->-r ../requirements.txt (line 5)) (4.13.0)
# Requirement already satisfied: certifi in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb->-r ../requirements.txt (line 5)) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb->-r ../requirements.txt (line 5)) (1.0.9)
# Requirement already satisfied: idna in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb->-r ../requirements.txt (line 5)) (3.18)
# Requirement already satisfied: h11>=0.16 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb->-r ../requirements.txt (line 5)) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb->-r ../requirements.txt (line 5)) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb->-r ../requirements.txt (line 5)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb->-r ../requirements.txt (line 5)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb->-r ../requirements.txt (line 5)) (2026.5.1)
# Requirement already satisfied: six>=1.9.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 5)) (1.17.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 5)) (1.9.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 5)) (2.7.0)
# Requirement already satisfied: durationpy>=0.7 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 5)) (0.10)
# Requirement already satisfied: aiohttp<4.0.0,>=3.13.5 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 5)) (3.14.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.42.1 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r ../requirements.txt (line 5)) (1.42.1)
# Requirement already satisfied: opentelemetry-proto==1.42.1 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r ../requirements.txt (line 5)) (1.42.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.63b1 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from opentelemetry-sdk>=1.2.0->chromadb->-r ../requirements.txt (line 5)) (0.63b1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from pydantic>=2.0->chromadb->-r ../requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from pydantic>=2.0->chromadb->-r ../requirements.txt (line 5)) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from pydantic>=2.0->chromadb->-r ../requirements.txt (line 5)) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from pydantic-settings>=2.0->chromadb->-r ../requirements.txt (line 5)) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from requests->insightface->-r ../requirements.txt (line 3)) (3.4.7)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->-r ../requirements.txt (line 8)) (3.3.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from rich>=10.11.0->chromadb->-r ../requirements.txt (line 5)) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from rich>=10.11.0->chromadb->-r ../requirements.txt (line 5)) (2.20.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch->-r ../requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from tokenizers>=0.13.2->chromadb->-r ../requirements.txt (line 5)) (1.19.0)
# Requirement already satisfied: click>=8.2.1 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from typer>=0.9.0->chromadb->-r ../requirements.txt (line 5)) (8.4.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from typer>=0.9.0->chromadb->-r ../requirements.txt (line 5)) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from typer>=0.9.0->chromadb->-r ../requirements.txt (line 5)) (0.0.4)
# Requirement already satisfied: httptools>=0.8.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r ../requirements.txt (line 5)) (0.8.0)
# Requirement already satisfied: uvloop>=0.15.1 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r ../requirements.txt (line 5)) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r ../requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: websockets>=10.4 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r ../requirements.txt (line 5)) (16.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from beautifulsoup4->gdown->-r ../requirements.txt (line 6)) (2.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from jinja2->torch->-r ../requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from onnx->insightface->-r ../requirements.txt (line 3)) (0.5.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from requests[socks]->gdown->-r ../requirements.txt (line 6)) (1.7.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from scikit-image->insightface->-r ../requirements.txt (line 3)) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from scikit-image->insightface->-r ../requirements.txt (line 3)) (2026.6.1)
# Requirement already satisfied: lazy-loader>=0.4 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from scikit-image->insightface->-r ../requirements.txt (line 3)) (0.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 5)) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 5)) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 5)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 5)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 5)) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 5)) (1.24.2)
# Requirement already satisfied: cffi>=2.0.0 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from cryptography>=38.0.3->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client->-r ../requirements.txt (line 7)) (2.0.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb->-r ../requirements.txt (line 5)) (1.5.1)
# Requirement already satisfied: mdurl~=0.1 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb->-r ../requirements.txt (line 5)) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client->-r ../requirements.txt (line 7)) (0.6.3)
# Requirement already satisfied: pycparser in /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client->-r ../requirements.txt (line 7)) (3.0)
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# 0

# %%
import cv2, numpy as np, matplotlib.pyplot as plt
import torch
import insightface
print('torch:', torch.__version__, '| CUDA:', torch.cuda.is_available())
print('insightface:', insightface.__version__)
print('OpenCV:', cv2.__version__)
# Out:
# torch: 2.12.0+cu130 | CUDA: False
# insightface: 1.0.1
# OpenCV: 4.13.0
# /home/drzewo/szt_mag/face/.venv/lib/python3.12/site-packages/torch/cuda/__init__.py:187: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 12020). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at /pytorch/c10/cuda/CUDAFunctions.cpp:119.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
import sys; sys.path.insert(0, '..')
from src.model import get_insightface_model, get_embedding
from src.database import EmbeddingDB
from src.metrics import compute_far_frr
from src.degradation import add_noise_to_psnr, apply_jpeg
print('Wszystkie moduły załadowane pomyślnie.')
# Out:
# Wszystkie moduły załadowane pomyślnie.

# %%
# Test modelu na przykładowym obrazku
app = get_insightface_model('buffalo_l', ctx_id=0)  # ctx_id=-1 dla CPU
print('Model załadowany.')
# Out:
# Model załadowany.
